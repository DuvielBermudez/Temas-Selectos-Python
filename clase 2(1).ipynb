# %%
nombre = input('Cual es tu nomnbre?') #recibir un nombre
print('Hola', nombre) # para mosstrar informacion en la pantalla
# Out:
# Cual es tu nomnbre?Duviel
# Hola Duviel

# %% [markdown]
# Para hacer anotaciones en el texto se pone el simbolo numeral es distinto al matlab que se utiliza el simbolo de porciento %

# %%
a = 10
b = 3
a/b
a//b
# Out:
# 3

# %%
a%b #modulo (residuo)
# Out:
# 1

# %%
2**4+(4*5)
# Out:
# 36

# %%
a = 7
b = 10
a>b
# Out:
# False

# %%
(5<3) and (4<5)
# Out:
# False

# %%
(5>3)or(2>4)
(100>3)or (4<8)
# Out:
# True

# %%
not(4<5)
# Out:
# False

# %% [markdown]
# Resolver ecuaciones

# %%
a = -1
b = 2
c = 3
import math #para resolver ecuaciones con raiz cuadrada se importa ese modulo math
x1 = ((-b)+math.sqrt(b**2-4*a*c))/2*a  #ecuacion del discriminante
x2 = ((-b)-math.sqrt(b**2-4*a*c))/2*a

# %%
x1
# Out:
# -1.0

# %%
x2
# Out:
# 3.0

# %%
x = -70
if x < 0:# hay que dear enter sino no ejecuta el comando
  print('es negativo')
# Out:
# es negativo

# %%
if x< 0:#si
  print('x es negativo')
elif x ==0:#entonces
  print ('x es igual a cero')

else:# de otro modo
  print('x es postivo')
# Out:
# x es negativo

# %%
n = int(input('ingresa un numero: '))# es la funcion input permite hacer una especie de programita y el int es para que lo reconosca como numero y no como texto
if n>0:
  print('el numero es positivo')
elif n<0:
  print('el numero es negativo')
else:
  print('el numero es cero')
# Out:
# ingresa un numero: 0
# el numero es cero

# %%
#declaro las variables
a = 1
b = 4
c = 5
# escribo la operacion
D = b**2-4*a*c
if D>0:
  print('son raices reales distintas')
elif D<0:
  print('son raices complejas conjugadas')
else:# este no lleva condicion ya que si no se cumple ni una ni otra ya se cumple lo que queda
  print('D=0 son raices doble')
# Out:
# son raices complejas conjugadas

# %%
# escribo la operacion
calificacion = float(input('ingresa una calificacion(0-10): '))

if calificacion >= 8.6 and calificacion <=10:
  print('calificacion MB')
elif calificacion >= 7.6 and calificacion <=8.6:
  print('calificacion b')
elif calificacion >= 6 and calificacion <=7.6:
  print('calificacion S')
else:# <6 NA
  print('Calificacion NA')
# Out:
# ingresa una calificacion(0-10): 8.2
# calificacion b
